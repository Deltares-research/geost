# %% [markdown]
# # Reading XML files
#
# This example demonstrates how GeoST extracts data from XML files (such as BRO XML files) and
# how to retrieve additional data that is not extracted by default by extending the methodology.
#
# GeoST reads data from XML files using a `schema` that describes the structure of the file
# (i.e., where to find specific elements) and determines where the information ends up in the
# resulting `Collection`. Under the hood, GeoST uses the
# [lxml library](https://lxml.de/index.html) for XML parsing, which we will also use in this
# tutorial to demonstrate some basic principles.
#
# Borehole and CPT data in the Netherlands are distributed through a public national database:
# the BRO ("Basis Registratie Ondergrond"). The BRO contains five main sources of subsurface
# data:
#
# - Geological boreholes (BHR-G objects)
# - Geotechnical boreholes (BHR-GT objects or BHR-GT-samples when retrieving grain size sample
#   data)
# - Pedological boreholes (BHR-P objects)
# - Cone Penetration Tests (CPT objects)
# - Pedological soil profile descriptions (SFR objects)
#
# Downloading any of the above data sources from
# [BROloket](https://www.broloket.nl/ondergrondgegevens) results in a set of XML files for the
# requested objects. GeoST can be used to read the XML files for each of these data sources
# (see the [available read functions](../user_guide/reading_data.ipynb#survey-data) for each
# object).
#
# Sometimes, XML data for one of the above objects may also be provided by companies (e.g.,
# Wiertsema). These files can differ slightly in structure from BRO XML files, but GeoST can
# work with these files as well. For this tutorial, we will demonstrate how data is extracted
# from a BHR-G XML file downloaded from the BRO. The principle is the same for the other data
# sources.
#
# We will begin with the necessary imports.

# %%
from lxml import etree

import geost
from geost.io import xml

bhrg_file = geost.data.bhrg_bro()  # BHR-G XML file for tutorial

# %% [markdown]
# ## Reading with default schema
#
# As mentioned above, a `schema` is used to read XML files, and GeoST contains predefined schemas
# for each supported data source. These schemas are used to retrieve the most important header
# attributes (e.g., `"nr"`, `"x"`, `"y"`, and `"surface"`) as well as basic data attributes.
# For BHR-G objects, these include attributes such as `"top"`, `"bottom"`, and `"lithology"`.
#
# If you are only interested in basic attributes or want to perform a quick inspection, you can
# simply use the default reader functions without worrying about schemas or other details. The
# code below shows how easily a BHR-G file can be read. The result is a `Collection`
# containing a header and data attribute.

# %%
bhrg = geost.read_bhrg(bhrg_file)
print(bhrg.header)
print(bhrg.data)
print(f"Retrieved header attributes: {bhrg.header.columns}")
print(f"Retrieved data attributes: {bhrg.data.columns}")

# %% [markdown]
# ## Schema
#
# We can see that using the predefined `schema` already retrieves many of the important
# attributes from the XML file. However, some users may need additional data attributes because
# they are interested in other information that may be relevant to their specific questions. For
# this, we will explore the `schema` and the XML structure in more detail.
#
# Let's first take a look at the predefined schema that is used by default by
# `geost.read_bhrg`. We will use `pprint` to display the structure of the schema more clearly.

# %%
from pprint import pprint

bhrg_schema = xml.schemas.bhrg[
    "BRO"
]  # This would be `xml.schemas.bhrgt` for BHR-GT files

pprint(
    bhrg_schema, sort_dicts=False
)  # Use `sort_dicts=False` to keep the order of the schema

# %% [markdown]
# You may already recognize some of the header attributes from the `Collection` above,
# such as `"nr"`, `"crs"`, and `"surface"`. The simplest way to explain the schema above in
# relation to the resulting `Collection` is that the `"data"` key determines what is
# included in the data table, while all other keys end up in the header table. Each key in the
# schema contains a subdictionary that "tells `geost.read_bhrg` what to do" for that key.
#
# The dictionaries for keys that end up in the header can contain the keys `"xpath"`,
# `"resolver"`, and `"el-attr"`. As you can see, they can contain one or all of these keys.
# Below is a short description of each:
#
# - `"xpath"`: Path to the desired element in the XML structure. This is always required;
#   otherwise, nothing will be retrieved.
# - `"resolver"`: Python function (if necessary) to extract or transform data in a specific
#   way. For example, it can be used to convert a text value to a float.
# - `"el-attr"`: XML elements can have attributes, such as a `"text"` attribute. This ensures
#   that the specified attribute is used as the result or as input for the resolver.
#
# The dictionary under the `"data"` key in the schema also contains `"xpath"` and `"resolver"`,
# but `"el-attr"` cannot be used here. Instead, it contains a `"layer-attributes"` key which,
# as the name suggests, extracts the desired attributes for each borehole layer in the BHR-G
# object. For now, the predefined schema only extracts the `"upperBoundary"`,
# `"lowerBoundary"`, and `"soilNameNEN5104"` attributes of each layer. We will show how the
# schema above can be extended to retrieve additional data.
#
# ## Retrieving additional attributes
#
# Since `"upperBoundary"`, `"lowerBoundary"`, and `"soilNameNEN5104"` may not provide enough
# information for every purpose, it may be desirable to retrieve additional layer attributes.
# Let's take a look at an element in the XML file that contains the data for a single layer and
# see what additional attributes are available. Normally, you could inspect the entire XML file
# in a text editor such as `Notepad++`. In this tutorial, however, we will retrieve and print
# the layer element using `lxml` to see which attributes are present.

# %%
xml_tree = etree.parse(
    bhrg_file
).getroot()  # Read the XML file and get the root element

# Unfortunately, the path to a layer element from the root is really long
path_layer_element = "dispatchDocument/BHR_G_O/boreholeSampleDescription/bhrgcom:BoreholeSampleDescription/bhrgcom:descriptiveBoreholeLog/bhrgcom:DescriptiveBoreholeLog/bhrgcom:layer/bhrgcom:Layer"
layer = xml_tree.find(path_layer_element, namespaces=xml_tree.nsmap)
print(etree.tostring(layer, pretty_print=True, encoding="unicode"))

# %% [markdown]
# As we can see, additional attributes are available, such as "gravelContentClass",
# "carbonateContentClass", and "colour". These can easily be retrieved by adding them to the
# list of "layer-attributes" in the schema and using the new schema as input to read the data.
# Let's use the updated schema to read the XML file again and check the data attribute of the
# resulting `Collection` to verify that it works.

# %%
extra_attributes = ["gravelContentClass", "carbonateContentClass", "colour"]
bhrg_schema["data"]["layer-attributes"].extend(
    extra_attributes
)  # Add the list of extra attributes to the schema

bhrg = geost.read_bhrg(bhrg_file, schema=bhrg_schema)
bhrg.data

# %% [markdown]
# Even though the extra attributes have the value "onbekend" (i.e., unknown) for every layer in
# this particular borehole, we can see that they were successfully retrieved from the XML file.
#
# ## Extending the schema
#
# So far, we have shown how to extend a schema to retrieve additional layer attributes. However,
# the schema can also be extended to retrieve other information that will be added to the header.
# Before we show how this can be done, it is worth taking a closer look at the XML file itself.

# %%
# We can print the XML tree that we loaded before
print(etree.tostring(xml_tree, pretty_print=True, encoding="unicode"))

# %% [markdown]
# By inspecting the XML tree, we can see where specific elements can be found and how these
# relate to the "xpath" keys in the schema. The indentation level of the XML tree represents
# the hierarchy of so-called "elements" and "child-elements".
#
# The `geost.read_bhrg` function begins searching for the data from the `<dispatchDocument>`
# element because the schema defines this as the "payload_root". This element can contain one or
# more child-elements that hold the actual borehole data: `<BHR_G_O gml:id="BRO_xxxx">` elements.
# When "payload_root" is not defined in an input schema, the function begins searching from the
# root element of the tree ("dispatchDataResponse"), which may lead to unexpected results. We
# can see that the ID of the borehole is stored in the `<brocom:broId>` element and that this
# was used as the "xpath" entry to retrieve "nr" as the borehole ID.
#
# We can extend the schema to retrieve additional header information by adding an extra
# dictionary with at least an "xpath" entry and, if needed, entries for "resolver" and/or
# "el-attr". If we look at the complete XML tree above, we can see that it contains a
# `<registrationHistory>` element with child-elements containing registration dates for this
# BHR-G object. Let's assume for now that this information is relevant to us and that we
# therefore want to retrieve it as additional header information. We can achieve this by
# extending the schema as shown below. We will first retrieve the data by specifying where it
# is located in the XML tree and then read the file again.

# %%
date = {"xpath": "registrationHistory/brocom:registrationCompletionTime"}
bhrg_schema["date"] = date

bhrg = geost.read_bhrg(bhrg_file, schema=bhrg_schema)
print(bhrg.header)  # Print the header to see the new date attribute
print(
    f"\nDtype of date: {bhrg.header['date'].dtypes}"
)  # Print the data types of the header attributes

# %% [markdown]
# ### Adding your own resolver
#
# The date has now been nicely added to the header of the `Collection`. However, the
# resulting data type of the date is "object", which is a "string-like" data type in Pandas
# DataFrames. Since this is a date, it may be more convenient to represent it directly as a
# "datetime" type. We can achieve this by adding our own "resolver" function that translates
# the text attribute of the retrieved date element into a datetime type. Let's write our
# helper function and update the schema accordingly.

# %%
import pandas as pd


def to_datetime(date_str):
    """Convert a date string to a pandas datetime object."""
    return pd.to_datetime(date_str)


date = {
    "xpath": "registrationHistory/brocom:registrationCompletionTime",
    "resolver": to_datetime,
    "el-attr": "text",  # This ensures we use the text content of the element
}
bhrg_schema["date"] = date

bhrg = geost.read_bhrg(bhrg_file, schema=bhrg_schema)

print(bhrg.header)  # Print the header to see the new date attribute
print(
    f"\nDtype of date: {bhrg.header['date'].dtypes}"
)  # Print the data types of the header attributes

# %% [markdown]
# Now the data type is "datetime64[ns, UTC+01:00]", which is more convenient for operations
# involving date selections, for example. Of course, changing the data type of a date could
# also have been done in other ways, without adding a resolver. However, in some cases, the
# data in elements needs to be processed in such specific ways that adding our own resolvers
# is necessary.
#
# ## Very specific needs
#
# Sometimes, the requirements may become so specific that GeoST can no longer load the data
# into `Collection` objects. This may occur when schemas become too specific, for example when
# resolvers return complex data structures that cannot be easily added as rows to DataFrames.
# This is not necessarily a problem, because GeoST still provides functionality to parse the
# XML files. However, instead of returning a `Collection` object, the parser returns a
# dictionary containing the retrieved data according to the schema.
#
# Let's assume for now that the `bhrg_schema` has become too specific and that the standard
# reader functions are no longer sufficient. The example below shows how you can still use
# GeoST to retrieve the data for further use in your own application, or continue processing
# it into a format that is compatible with GeoST objects.

# %%
data = xml.read_bhrg(
    bhrg_file, schema=bhrg_schema
)  # bhrg_schema is now our "too specific" schema
pprint(data, sort_dicts=False)

# %% [markdown]
# As you can see, a clean dictionary is still returned, containing the data for each key you
# have added to your schema, and you can continue working with the data. As mentioned at the
# beginning of this tutorial, reading XML files for the other data sources (BHR-GT, BHR-P, CPT,
# and SFR) works in exactly the same way and offers the same possibilities.
